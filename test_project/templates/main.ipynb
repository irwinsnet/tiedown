# %% [markdown]
# {% outline .I.A %}

# %% [markdown]
# ## {{ skip }} This is a header cell

# %% [markdown]
# {% insert content %}

# %%
# Here is some random content

# %% [markdown]
# {% insert other_stuff  %}

# %% [markdown]
# ## {{ skip }} This is a footer cell
