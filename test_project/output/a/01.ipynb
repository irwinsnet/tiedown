# %% [markdown]
# ## This is a header cell

# %% [markdown]
# ## I. THIS IS NOT THE TITLE OF CHAPTER 1
# # This is the title of Chapter 1
#
# ### A. First Chapter

# %% [markdown]
# [Link to Lesson 2](../x/02.ipynb)

# %%
x = 2 + 5
x
# Out:
# 7

# %%
# Here is some random content
import yaml
data = "outline: .I.A"
yaml.load(data, Loader=yaml.FullLoader)
# Out:
# {'outline': '.I.A'}

# %%
print("Hello knotbook")

# %% [markdown]
# ### B. Internal Link <span id="link_demo"/>

# %% [markdown]
# ## This is a footer cell
