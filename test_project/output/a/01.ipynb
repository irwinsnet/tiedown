# %% [markdown]
# {% target lesson_1 %}

# %% [markdown]
# {% outline .I.A %}

# %% [markdown]
# ## {{ skip }} This is a header cell

# %% [markdown]
# ## I. THIS IS NOT THE TITLE OF CHAPTER 1
# # This is the title of Chapter 1
#
# ### A. First Chapter {{ chapter }}

# %% [markdown]
# [Link to Lesson 2](../x/02.ipynb)

# %%
x = 2 + 5
x
# Out:
# 7

# %%
# Here is some random content

# %%
print("Hello knotbook")

# %% [markdown]
# ## {{ skip }} This is a footer cell
