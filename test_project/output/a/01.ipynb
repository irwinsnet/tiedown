# %% [markdown]
# {% target lesson_1 %}

# %% [markdown]
# ## This is a header cell

# %% [markdown]
# {% insert content %}

# %%
# Here is some random content

# %% [markdown]
# {% insert other_stuff  %}

# %% [markdown]
# ## This is a footer cell

# %% [markdown]
# <h3 id="id1">Header</h3>
