# %% [markdown]
# {% target lesson_1 %}

# %% [markdown]
# {% block content %}

# %% [markdown]
# ## THIS IS NOT THE TITLE OF CHAPTER 1
# # This is the title of Chapter 1
#
# ### First Chapter {{ chapter }}

# %% [markdown]
# [Link to Lesson 2]{{ rel_link lesson_2 }}

# %%
x = 2 + 5
x
# Out:
# 7

# %% [markdown]
# {% endblock %}

# %% [markdown]
# {% block other_stuff %}

# %%
print("Hello knotbook")

# %% [markdown]
# {% endblock %}
