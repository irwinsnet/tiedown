# %% [raw]
# target: lesson_2
# toc_entry: This is the title of Chapter 2

# %% [raw]
# block: content

# %% [markdown]
# ### Chapter {{ chapter }}

# %%
x = 2 + 5
x
# Out:
# 7

# %% [markdown]
# * List item 1
# * List item 2
# * List item 3

# %% [raw]
# endblock:
