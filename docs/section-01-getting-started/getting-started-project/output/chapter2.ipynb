# %% [markdown]
# <span id="cid1"/>
#
# [Table of Contents](table-of-contents.ipynb)
# ####  Tiedown - Getting Started Example

# %% [markdown]
# <span id="cid2"/>
#
# # Chapter 2: An Example Content Notebook
# This is an example Tiedown content notebook. Content notebooks contain markdown and code cells.

# %% [markdown]
# <span id="cid3"/>
#
# ## I. An Example Code Cell (Chapter 2)

# %%
# Code Cell
import math
print(math.exp(1))

# %% [markdown]
# <span id="cid4"/>
#
# ## II. An Example Markdown Cell
# ### A. A Relative Link
# [Link to Chapter 1](chapter1.ipynb)

# %% [markdown]
# <span id="cid5"/>
#
# [Table of Contents](table-of-contents.ipynb)
