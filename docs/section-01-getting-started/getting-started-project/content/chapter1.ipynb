# %% [raw]
# label: chapter-1
# block: content

# %% [markdown]
# # Chapter 1: An Example Content Notebook
# This is an example Tiedown content notebook. Content notebooks contain markdown and code cells.

# %% [markdown]
# ## An Example Code Cell

# %%
# Code Cell
import math
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %% [markdown]
# ## An Example Markdown Cell
# ### A Relative Link
# [Link to Chapter 2]({{ rel_path: chapter-2 }})

# %% [raw]
# endblock:
