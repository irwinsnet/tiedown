# %% [raw]
# label: chapter-2
# block: content

# %% [markdown]
# # Chapter 2: An Example Content Notebook
# This is an example Tiedown content notebook. Content notebooks contain markdown and code cells.

# %% [markdown]
# ## An Example Code Cell (Chapter 2)

# %%
# Code Cell
import math
print(math.exp(1))
# Out:
# 2.718281828459045

# %% [markdown]
# ## An Example Markdown Cell
# ### A Relative Link
# [Link to Chapter 1]{{ rel_path: chapter-1 }}

# %% [raw]
# endblock:
