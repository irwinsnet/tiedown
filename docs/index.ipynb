# %% [markdown]
# # Tiedown - Tools for Joining Jupyter Notebooks<span id="cid1"/>
# Tiedown is a Python package for managing sets of related, hyperlinked Jupyter or Google Colab notebooks, where each notebook is a section of a larger document. Tiedown provides the following features:
# * Templates
# * Automatic Section Numbering
# * Table of Content Generation
# * Term Index
# * Relative Hyperlinks
#
# Start with section 1, *Getting Started* if you are new to Tiedown.
#
# This documentation was created with Jupyter and Tiedown. The source files are in the *example_project* folder in the Tiedown Github repository.

# %% [markdown]
# ## Table of Contents<span id="cid2"/>
# 1. [Getting Started<span id="cid2"/>](section-01-getting-started/getting-started.ipynb)
# 2. [Project Structure<span id="cid2"/>](section-02-project-structure/project-structure.ipynb)
# 3. [Tiedown Instructions<span id="cid2"/>](section-03-tiedown-commands/tiedown-instructions.ipynb)
# 4. [Templates<span id="cid2"/>](section-04-templates/templates.ipynb)
# 5. [Section Numbering<span id="cid2"/>](section-05-numbering/section-numbering.ipynb)
# 6. [Including a Table of Contents](section-06-table-of-contents/table-of-contents.ipynb)
# 7. [Relative Links<span id="cid2"/>](section-07-links/links.ipynb)
