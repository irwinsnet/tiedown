# %% [raw]
# label: numbering
# toc_entry: Including a Table of Contents

# %% [raw]
# block: content

# %% [markdown]
# # Table of Contents
# {% index:
#     - Table of Contents
#     - toc: code %}
# {% ignore %}
# Tiedown maintains an ordered, internal list of each notebook. This is the default behavior - no actions are required. A table of contents (TOC) can be inserted into any notebook with the {{ toc }} insert.

# %% [markdown]
# ## Customizing the TOC
# {% index:
#     - toc_entry: code %}
# {% ignore %}
# Tiedown's default behavior is to use the text from the first top-level header within a notebook (single hash) for the notebook's entry in the table of contents. Use the `toc_entry` action to change the text that's used for the notebook's entry in the TOC. Place the `toc_entry` action in the notebook's configuration cell. For example:
#
# ```
# toc_entry: A Customized Entry for the Table of Contents
# ```

# %% [markdown]
# ## Excluding a Notebook from the TOC
# {% index:
#     - Table of Contents, Excluding Notebook
#     - toc_exclude: code %}
# {% ignore %}
# Place the `toc_excude` action in a notebook's configuration cell to exclude the notebook from the TOC.

# %% [raw]
# endblock
